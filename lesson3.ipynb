# %%
#conditional statements
if  -- one block-one option
if else two block- two options
if elif else multi blocks

# %%
condition
conditional operatorts

> greater than
< lessthan
>= greater than or equal
<= lessthan or equal
== equal
!= not equal

# %%
# 10 > 100 logical-expression, boolen-expression 

# a + 23 / 4
# Out:
# False

# %%
marks = 65
passing = 60
marks >= passing
# Out:
# True

# %%
keyword condtion:
 efewr
 sadfa
 asdf
 df
 adfg
 asdf

asdf
asdfsa
as

# %%
if marks >= passing:
    print("Congratulations you're passed you'have obtained", marks)

# %%
if marks >= passing:
    print("Congratulations you're passed you'have obtained", marks)
else:
    print("sorry, you're Failed try agian")
# Out:
# Congratulations you're passed you'have obtained 65
